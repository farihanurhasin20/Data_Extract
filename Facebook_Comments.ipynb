# %%
import time

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# Set up headless mode (optional)
chrome_options = Options()
chrome_options.add_argument("--headless")  # This will run the browser in the background

# Path to the chromedriver
driver_path = "C:/chromedriver/chromedriver.exe"  # Raw string to avoid escape sequence error
service = Service(driver_path)

#C:\Users\opusdev\Downloads\chromedriver-win64\chromedriver-win64
#C:\Users\opusdev\Downloads\chromedriver-win64\chromedriver.exe

#Set up WebDriver
#service = Service("path/to/chromedriver")  # Replace with your chromedriver path
# driver = webdriver.Chrome(service=service)

# Initialize the WebDriver
driver = webdriver.Chrome(service=service)


# # Path to the chromedriver
# driver_path = r"C:\Users\radif\Downloads\Compressed\chromedriver-win64\chromedriver.exe"  # Raw string to avoid escape sequence error
# service = Service(driver_path)

# Initialize the WebDriver
driver = webdriver.Chrome(service=service, options=chrome_options)




# Open the Facebook post URL
url = "https://www.facebook.com/share/p/15Zgn7QQYw/"
driver.get(url)

# Wait for the page to load (adjust time if needed)
time.sleep(10)  # Increased wait time for the page to load

try:
    # Wait for the post message to be visible and extract it
    post_message = WebDriverWait(driver, 15).until(
        EC.presence_of_element_located((By.XPATH, "//div[contains(@class, 'userContent')]"))
    )
    print("Post Message:", post_message.text)
except Exception as e:
    print("Post message not found:", e)

try:
    # Wait for the post time to be visible and extract it
    post_time = WebDriverWait(driver, 15).until(
        EC.presence_of_element_located((By.XPATH, "//abbr"))
    )
    print("Post Time:", post_time.text)
except Exception as e:
    print("Post time not found:", e)

# Extract comments based on the aria-label attribute
try:
    comments_section = driver.find_elements(By.XPATH, "//div[contains(@aria-label, 'Comment by')]")
    for comment in comments_section:
        comment_text = comment.text
        print("Comment:", comment_text)
except Exception as e:
    print("Error extracting comments:", e)

# Close the browser window
driver.quit()
# Out:
# Post message not found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF77D420315+28725]
# 	(No symbol) [0x00007FF77D382B00]
# 	(No symbol) [0x00007FF77D21510A]
# 	(No symbol) [0x00007FF77D2693D2]
# 	(No symbol) [0x00007FF77D2695FC]
# 	(No symbol) [0x00007FF77D2B3407]
# 	(No symbol) [0x00007FF77D28FFEF]
# 	(No symbol) [0x00007FF77D2B0181]
# 	(No symbol) [0x00007FF77D28FD53]
# 	(No symbol) [0x00007FF77D25A0E3]
# 	(No symbol) [0x00007FF77D25B471]
# 	GetHandleVerifier [0x00007FF77D74F31D+3366973]
# 	GetHandleVerifier [0x00007FF77D761300+3440672]
# 	GetHandleVerifier [0x00007FF77D75790D+3401261]
# 	GetHandleVerifier [0x00007FF77D4EAACB+858091]
# 	(No symbol) [0x00007FF77D38E76F]
# 	(No symbol) [0x00007FF77D38A324]
# 	(No symbol) [0x00007FF77D38A4BD]
# 	(No symbol) [0x00007FF77D378B89]
# 	BaseThreadInitThunk [0x00007FF819597374+20]
# 	RtlUserThreadStart [0x00007FF81A75CC91+33]
#
# Post time not found: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF77D420315+28725]
# ...
